# %%
import pandas as pd
import numpy as np

# %%
mc=pd.read_csv('mc.csv')

# %%
mc
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0  21408I70789   272.0   3055.050000   3065.150000
# 1                2      1  76462I70374   712.0  12122.000000  12124.750000
# 2                3      1  17943I70372   535.0   1398.000000   1398.000000
# 3                4      1  55773I70781   241.0     21.228000     21.228000
# 4                5      1  03813I82730   947.0    150.619333    150.619333
# ...            ...    ...          ...     ...           ...           ...
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
# ...

# %%
mc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 37 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Unnamed: 0            209593 non-null  int64
#  1   label                 209593 non-null  int64
#  2   msisdn                209593 non-null  object
#  3   aon                   209593 non-null  float64
#  4   daily_decr30          209593 non-null  float64
#  5   daily_decr90          209593 non-null  float64
#  6   rental30              209593 non-null  float64
#  7   rental90              209593 non-null  float64
#  8   last_rech_date_ma     209593 non-null  float64
#  9   last_rech_date_da     209593 non-null  float64
#  10  last_rech_amt_ma      209593 non-null  int64
#  11  cnt_ma_rech30         209593 non-null  int64
#  12  fr_ma_rech30          209593 non-null  float64
#  13  sumamnt_ma_rech30     209593 non-null  float64
# ...

# %%
mc.describe()
# Out:
#           Unnamed: 0          label            aon   daily_decr30  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean   104797.000000       0.875177    8112.343445    5381.402289
# std     60504.431823       0.330519   75696.082531    9220.623400
# min         1.000000       0.000000     -48.000000     -93.012667
# 25%     52399.000000       1.000000     246.000000      42.440000
# 50%    104797.000000       1.000000     527.000000    1469.175667
# 75%    157195.000000       1.000000     982.000000    7244.000000
# max    209593.000000       1.000000  999860.755168  265926.000000
#
#         daily_decr90       rental30       rental90  last_rech_date_ma  \
# count  209593.000000  209593.000000  209593.000000      209593.000000
# mean     6082.515068    2692.581910    3483.406534        3755.847800
# std     10918.812767    4308.586781    5770.461279       53905.892230
# min       -93.012667  -23737.140000  -24720.580000         -29.000000
# ...

# %% [markdown]
# # Checking Feature cnt_ma_rech30 and fr_ma_rech30

# %%
mc[['cnt_ma_rech30','fr_ma_rech30']]
# Out:
#         cnt_ma_rech30  fr_ma_rech30
# 0                   2          21.0
# 1                   1           0.0
# 2                   1           0.0
# 3                   0           0.0
# 4                   7           2.0
# ...               ...           ...
# 209588              3           2.0
# 209589              4           1.0
# 209590              5           8.0
# 209591              5           4.0
# 209592              2           1.0
#
# [209593 rows x 2 columns]

# %%
mc['fr_ma_rech30'].value_counts()
# Out:
# 0.000000         78683
# 1.000000         22370
# 2.000000         18849
# 3.000000         14306
# 4.000000         11194
#                  ...
# 832329.313736        1
# 621153.282118        1
# 903140.291804        1
# 774114.500615        1
# 978141.221916        1
# Name: fr_ma_rech30, Length: 1083, dtype: int64

# %%
mc['cnt_ma_rech30'].value_counts()
# Out:
# 1      37238
# 2      31216
# 0      27979
# 3      25519
# 4      20258
#        ...
# 64         1
# 63         1
# 59         1
# 50         1
# 115        1
# Name: cnt_ma_rech30, Length: 71, dtype: int64

# %%
import seaborn as sb
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15,8))
plt.xticks(rotation=50)
sb.countplot(mc['cnt_ma_rech30'])
plt.show()

# %% [markdown]
# The max count Main account Recharge in avg 30 days was 1.

# %%
a=mc['fr_ma_rech30'].sort_values(ascending=False)

# %%
plt.figure(figsize=(15,8))
plt.xticks(rotation=50,ha='right')
sb.countplot(a.head(20))
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.xticks(rotation=50)
sb.countplot(a.tail(100000))
plt.show()

# %%
sb.violinplot(mc['fr_ma_rech30'])

# %%
sb.violinplot(mc['cnt_ma_rech30'])

# %%
sb.distplot(mc['cnt_ma_rech30'])

# %%
sb.distplot(mc['fr_ma_rech30'])

# %%
mc['cnt_ma_rech30'].plot(kind='kde',color='red')

# %%
mc['fr_ma_rech30'].plot(kind='kde',color='red')

# %%
sb.boxplot(mc['cnt_ma_rech30'])

# %%
sb.boxplot(mc['fr_ma_rech30'])

# %% [markdown]
# Data highly skewed. And having a lot of outliers.

# %%
c=mc[['fr_ma_rech30','label']]

# %%
c.corr()
# Out:
#               fr_ma_rech30    label
# fr_ma_rech30       1.00000  0.00133
# label              0.00133  1.00000

# %%
sb.heatmap(c.corr())

# %%
c=mc[['cnt_ma_rech30','label']]

# %%
c.corr()
# Out:
#                cnt_ma_rech30     label
# cnt_ma_rech30       1.000000  0.237331
# label               0.237331  1.000000

# %%
sb.heatmap(c.corr())

# %%
d=mc[['fr_ma_rech30','cnt_ma_rech30']]

# %%
d.corr()
# Out:
#                fr_ma_rech30  cnt_ma_rech30
# fr_ma_rech30       1.000000       0.001669
# cnt_ma_rech30      0.001669       1.000000

# %%
sb.heatmap(d.corr())

# %%
mc.rename(columns={'label':'Defaulter'},inplace=True)
mc.rename(columns={'msisdn':'Mobile'},inplace=True)
mc.rename(columns={'aon':'MobileAge(days)'},inplace=True)
mc.rename(columns={'daily_decr30':'AmountSpentMA(Avg30days)'},inplace=True)
mc.rename(columns={'daily_decr90':'AmountSpentMA(Avg90days)'},inplace=True)
mc.rename(columns={'last_rech_date_ma':'Days_since_last_rech_MA'},inplace=True)
mc.rename(columns={'last_rech_date_da':'Days_since_last_rech_DA'},inplace=True)
mc.rename(columns={'last_rech_amt_ma':'Last_rech_amt_MA'},inplace=True)
mc.rename(columns={'cnt_ma_rech30':'MA_rech_No_30days'},inplace=True)
mc.rename(columns={'sumamnt_ma_rech30':'TA_charge_MA_30days'},inplace=True)
mc.rename(columns={'medianamnt_ma_rech30':'MedianAmt_chrg_30Days_MA'},inplace=True)
mc.rename(columns={'medianmarechprebal30':'MedianAmt_chrg_B430Days_MA'},inplace=True)
mc.rename(columns={'cnt_ma_rech90':'Freq_MA_rech_90days'},inplace=True)
mc.rename(columns={'sumamnt_ma_rech90':'TA_chrg_MA_90Days'},inplace=True)
mc.rename(columns={'medianamnt_ma_rech90':'MedianAmt_chrg_MA_90Days'},inplace=True)
mc.rename(columns={'medianmarechprebal90':'MedianAmt_chrg_B490Days_MA'},inplace=True)

# %%
mc.drop('Unnamed: 0',axis=1,inplace=True)

# %%
mc
# Out:
#         Defaulter       Mobile  MobileAge(days)  AmountSpentMA(Avg30days)  \
# 0               0  21408I70789            272.0               3055.050000
# 1               1  76462I70374            712.0              12122.000000
# 2               1  17943I70372            535.0               1398.000000
# 3               1  55773I70781            241.0                 21.228000
# 4               1  03813I82730            947.0                150.619333
# ...           ...          ...              ...                       ...
# 209588          1  22758I85348            404.0                151.872333
# 209589          1  95583I84455           1075.0                 36.936000
# 209590          1  28556I85350           1013.0              11843.111667
# 209591          1  59712I82733           1732.0              12488.228333
# 209592          1  65061I85339           1581.0               4489.362000
#
#         AmountSpentMA(Avg90days)  rental30  rental90  Days_since_last_rech_MA  \
# ...

# %% [markdown]
# # Checking the feature Mobile

# %%
mc['Mobile'].value_counts()
# Out:
# 04581I85330    7
# 47819I90840    7
# 87592I84456    6
# 43430I70786    6
# 67324I84453    6
#               ..
# 05938I90848    1
# 05851I84453    1
# 66223I70377    1
# 93052I90588    1
# 15600I90588    1
# Name: Mobile, Length: 186243, dtype: int64

# %%
p=mc['Mobile'].value_counts().sort_values(ascending=False)

# %%
sb.countplot(p)

# %% [markdown]
# Most of persons have a different mobile number. Data not relevant. Thus dropping column.

# %%
mc.drop('Mobile',axis=1,inplace=True)

# %% [markdown]
# # Checking Feature MobileAge(Days)

# %%
mc['MobileAge(days)'].value_counts()
# Out:
# 95.000000        392
# 92.000000        362
# 96.000000        357
# 99.000000        356
# 157.000000       349
#                 ...
# 752400.263562      1
# 565434.285440      1
# 931525.183027      1
# 929670.835962      1
# 972326.532821      1
# Name: MobileAge(days), Length: 4507, dtype: int64

# %%
sb.scatterplot(x='MobileAge(days)',y='Defaulter',data=mc)

# %%
sb.violinplot(mc['MobileAge(days)'])

# %%
sb.distplot(mc['MobileAge(days)'])

# %%
sb.boxplot(mc['MobileAge(days)'])

# %% [markdown]
# Data highly skewed and having huge outliers.

# %%
a=mc[['MobileAge(days)','Defaulter']]

# %%
a.corr()
# Out:
#                  MobileAge(days)  Defaulter
# MobileAge(days)         1.000000  -0.003785
# Defaulter              -0.003785   1.000000

# %%
sb.heatmap(a.corr())

# %%
#Feature has no co relation with the target variable. Thus dropping feature.

# %%
mc.drop('MobileAge(days)',axis=1,inplace=True)

# %% [markdown]
# # Checking feature AmountSpentMA(Avg30days)

# %%
mc['AmountSpentMA(Avg30days)'].value_counts()
# Out:
# 0.000000       4144
# 500.000000      829
# 1000.000000     569
# 700.000000      381
# 600.000000      354
#                ...
# 3565.333333       1
# 596.172000        1
# 700.126667        1
# 7604.514667       1
# 4108.476000       1
# Name: AmountSpentMA(Avg30days), Length: 147026, dtype: int64

# %%
#Max amount spent was 4108 while the max frequency was of 0.

# %%
b=mc['AmountSpentMA(Avg30days)'].sort_values(ascending=True)

# %%
b
# Out:
# 43057        -93.012667
# 179839       -46.215000
# 137843       -41.755000
# 37420        -35.346667
# 143636       -25.128000
#               ...
# 156048    183850.000000
# 180039    185313.000000
# 193084    212202.000000
# 157784    212364.000000
# 125063    265926.000000
# Name: AmountSpentMA(Avg30days), Length: 209593, dtype: float64

# %%
#The data in negative shows that the person's average spending was less than the mean.

# %%
mc['AmountSpentMA(Avg90days)'].plot.hist()

# %%
sb.scatterplot(x='AmountSpentMA(Avg30days)',y='Defaulter',data=mc)

# %%
a=mc[['AmountSpentMA(Avg30days)','Defaulter']]

# %%
a.corr()
# Out:
#                           AmountSpentMA(Avg30days)  Defaulter
# AmountSpentMA(Avg30days)                  1.000000   0.168298
# Defaulter                                 0.168298   1.000000

# %% [markdown]
# # Checking Feature AmountSpentMA(Avg90days)

# %%
mc['AmountSpentMA(Avg90days)'].value_counts()
# Out:
# 0.000        4063
# 500.000       781
# 1000.000      490
# 700.000       343
# 600.000       316
#              ...
# 784.600         1
# 84.276          1
# 12853.830       1
# 1307.920        1
# 16839.040       1
# Name: AmountSpentMA(Avg90days), Length: 158670, dtype: int64

# %%
mc['AmountSpentMA(Avg90days)'].sort_values(ascending=True)
# Out:
# 43057        -93.012667
# 179839       -46.215000
# 137843       -41.755000
# 37420        -35.346667
# 143636       -25.128000
#               ...
# 156048    231228.810000
# 180039    244906.760000
# 193084    254657.130000
# 23322     259525.000000
# 125063    320630.000000
# Name: AmountSpentMA(Avg90days), Length: 209593, dtype: float64

# %%
sb.distplot(mc['AmountSpentMA(Avg90days)'])

# %%
sb.scatterplot(x='AmountSpentMA(Avg90days)',y='AmountSpentMA(Avg30days)',data=mc,hue='Defaulter')

# %%
a=mc[['AmountSpentMA(Avg90days)','AmountSpentMA(Avg30days)']]

# %%
a.corr()
# Out:
#                           AmountSpentMA(Avg90days)  AmountSpentMA(Avg30days)
# AmountSpentMA(Avg90days)                  1.000000                  0.977704
# AmountSpentMA(Avg30days)                  0.977704                  1.000000

# %% [markdown]
# Both the columns are highly co related to each other.Thus dropping one feature to avoid Multi-colinearity.

# %%
mc.drop('AmountSpentMA(Avg30days)',axis=1,inplace=True)

# %%
cor=mc.corr()

# %%
cor
# Out:
#                             Defaulter  AmountSpentMA(Avg90days)  rental30  \
# Defaulter                    1.000000                  0.166150  0.058085
# AmountSpentMA(Avg90days)     0.166150                  1.000000  0.434685
# rental30                     0.058085                  0.434685  1.000000
# rental90                     0.075521                  0.471730  0.955237
# Days_since_last_rech_MA      0.003728                  0.000908 -0.001095
# Days_since_last_rech_DA      0.001711                 -0.001886  0.003261
# Last_rech_amt_MA             0.131804                  0.264131  0.127271
# MA_rech_No_30days            0.237331                  0.426707  0.233343
# fr_ma_rech30                 0.001330                 -0.000343 -0.001219
# TA_charge_MA_30days          0.202828                  0.603886  0.272649
# MedianAmt_chrg_30Days_MA     0.141490                  0.282960  0.129853
# MedianAmt_chrg_B430Days_MA  -0.004829                 -0.000746 -0.001415
# ...

# %%
plt.figure(figsize=(12,5))
sb.heatmap(cor)
plt.show()

# %%
cor['Defaulter'].sort_values(ascending=False)
# Out:
# Defaulter                     1.000000
# MA_rech_No_30days             0.237331
# Freq_MA_rech_90days           0.236392
# TA_chrg_MA_90Days             0.205793
# TA_charge_MA_30days           0.202828
# amnt_loans90                  0.199788
# amnt_loans30                  0.197272
# cnt_loans30                   0.196283
# AmountSpentMA(Avg90days)      0.166150
# MedianAmt_chrg_30Days_MA      0.141490
# Last_rech_amt_MA              0.131804
# MedianAmt_chrg_MA_90Days      0.120855
# fr_ma_rech90                  0.084385
# maxamnt_loans90               0.084144
# rental90                      0.075521
# rental30                      0.058085
# payback90                     0.049183
# payback30                     0.048336
# medianamnt_loans30            0.044589
# MedianAmt_chrg_B490Days_MA    0.039300
# medianamnt_loans90            0.035747
# cnt_loans90                   0.004733
# cnt_da_rech30                 0.003827
# Days_since_last_rech_MA       0.003728
# ...

# %% [markdown]
# # Checking Feature Rental30 and Rental90

# %%
a=mc[['rental30','rental90']]

# %%
a.corr()
# Out:
#           rental30  rental90
# rental30  1.000000  0.955237
# rental90  0.955237  1.000000

# %%
sb.scatterplot(x='rental30',y='rental90',data=mc,hue='Defaulter')

# %%
mc.rental30.value_counts()
# Out:
# 0.00        7566
# 200.13      1379
# 99.56       1020
# 400.26       530
# 199.12       461
#             ...
# 1103.55        1
# 6128.63        1
# 577.44         1
# 14544.75       1
# 2780.99        1
# Name: rental30, Length: 132148, dtype: int64

# %%
mc.rental90.value_counts()
# Out:
# 0.00        6918
# 200.13       913
# 99.56        767
# 60.00        691
# 90.00        685
#             ...
# 2973.25        1
# 601.86         1
# 13778.29       1
# 1477.55        1
# 5688.69        1
# Name: rental90, Length: 141033, dtype: int64

# %%
sb.boxplot(mc.rental30)

# %%
sb.boxplot(mc.rental90)

# %%
sb.violinplot(mc.rental30)

# %%
mc
# Out:
#         Defaulter  AmountSpentMA(Avg90days)  rental30  rental90  \
# 0               0               3065.150000    220.13    260.13
# 1               1              12124.750000   3691.26   3691.26
# 2               1               1398.000000    900.13    900.13
# 3               1                 21.228000    159.42    159.42
# 4               1                150.619333   1098.90   1098.90
# ...           ...                       ...       ...       ...
# 209588          1                151.872333   1089.19   1089.19
# 209589          1                 36.936000   1728.36   1728.36
# 209590          1              11904.350000   5861.83   8893.20
# 209591          1              12574.370000    411.83    984.58
# 209592          1               4534.820000    483.92    631.20
#
#         Days_since_last_rech_MA  Days_since_last_rech_DA  Last_rech_amt_MA  \
# 0                           2.0                      0.0              1539
# ...

# %% [markdown]
# # Checking Features Days_since_last_rech_DA and Days_since_last_rech_MA

# %%
mc.Days_since_last_rech_DA.value_counts()
# Out:
# 0.000000         202861
# 7.000000            163
# 8.000000            160
# 11.000000           149
# 13.000000           148
#                   ...
# 635922.630667         1
# 684933.969169         1
# 779774.580500         1
# 627095.756936         1
# 508947.450202         1
# Name: Days_since_last_rech_DA, Length: 1174, dtype: int64

# %%
mc.Days_since_last_rech_MA.value_counts()
# Out:
# 1.000000         47343
# 2.000000         26665
# 0.000000         20743
# 3.000000         19984
# 4.000000         15452
#                  ...
# 109.000000           1
# 582681.620610        1
# 708782.821544        1
# 906160.353101        1
# 990442.339913        1
# Name: Days_since_last_rech_MA, Length: 1186, dtype: int64

# %%
sb.scatterplot(x='Days_since_last_rech_DA',y='Days_since_last_rech_MA',data=mc,hue='Defaulter')

# %%
a=mc[['Days_since_last_rech_DA','Days_since_last_rech_MA']]

# %%
a.corr()
# Out:
#                          Days_since_last_rech_DA  Days_since_last_rech_MA
# Days_since_last_rech_DA                  1.00000                  0.00179
# Days_since_last_rech_MA                  0.00179                  1.00000

# %%
b=mc[['Days_since_last_rech_MA','Defaulter']]

# %%
b.corr()
# Out:
#                          Days_since_last_rech_MA  Defaulter
# Days_since_last_rech_MA                 1.000000   0.003728
# Defaulter                               0.003728   1.000000

# %%
c=mc[['Days_since_last_rech_DA','Defaulter']]

# %%
c.corr()
# Out:
#                          Days_since_last_rech_DA  Defaulter
# Days_since_last_rech_DA                 1.000000   0.001711
# Defaulter                               0.001711   1.000000

# %%
mc['Days_since_last_rech_DA'].plot.hist(bins=5,figsize=(10,7))

# %%
mc['Days_since_last_rech_MA'].plot.hist(bins=5,figsize=(10,7))

# %% [markdown]
# # Checking Feature Last_rech_amt_MA

# %%
mc.Last_rech_amt_MA
# Out:
# 0         1539
# 1         5787
# 2         1539
# 3          947
# 4         2309
#           ...
# 209588    4048
# 209589     773
# 209590    1539
# 209591     773
# 209592    7526
# Name: Last_rech_amt_MA, Length: 209593, dtype: int64

# %%
sb.distplot(mc['Last_rech_amt_MA'])

# %% [markdown]
# # Checking Target Feature

# %%
mc['Defaulter'].value_counts()
# Out:
# 1    183431
# 0     26162
# Name: Defaulter, dtype: int64

# %%
sb.countplot(mc['Defaulter'])

# %% [markdown]
# #### Highly Imabalanced Dataset

# %% [markdown]
# # Checking Feature pcircle and pdate

# %%
mc['pcircle'].value_counts()
# Out:
# UPW    209593
# Name: pcircle, dtype: int64

# %%
mc.drop('pcircle',axis=1,inplace=True)

# %%
mc['pdate'].value_counts()
# Out:
# 2016-07-04    3150
# 2016-07-05    3127
# 2016-07-07    3116
# 2016-06-20    3099
# 2016-06-17    3082
#               ...
# 2016-06-04    1559
# 2016-08-18    1407
# 2016-08-19    1132
# 2016-08-20     788
# 2016-08-21     324
# Name: pdate, Length: 82, dtype: int64

# %%
mc['pdate']=pd.to_datetime(mc['pdate'])

# %%
mc['pdate'].dt.month
# Out:
# 0         7
# 1         8
# 2         8
# 3         6
# 4         6
#          ..
# 209588    6
# 209589    6
# 209590    7
# 209591    7
# 209592    7
# Name: pdate, Length: 209593, dtype: int64

# %%
mc['Month']=mc['pdate'].dt.month

# %%
mc['pdate'].dt.day
# Out:
# 0         20
# 1         10
# 2         19
# 3          6
# 4         22
#           ..
# 209588    17
# 209589    12
# 209590    29
# 209591    25
# 209592     7
# Name: pdate, Length: 209593, dtype: int64

# %%
mc['Day']=mc['pdate'].dt.day

# %%
mc.drop('pdate',axis=1,inplace=True)

# %%
sb.countplot(mc['Month'])

# %%
sb.countplot(x=mc.Month,hue=mc.Defaulter)

# %%
plt.figure(figsize=(10,5))
sb.countplot(mc['Day'])
plt.show()

# %% [markdown]
# # Bi Variate Analysis of Feature with Target

# %%
a=mc.head(5000)

# %%
a
# Out:
#       Defaulter  AmountSpentMA(Avg90days)  rental30  rental90  \
# 0             0               3065.150000    220.13    260.13
# 1             1              12124.750000   3691.26   3691.26
# 2             1               1398.000000    900.13    900.13
# 3             1                 21.228000    159.42    159.42
# 4             1                150.619333   1098.90   1098.90
# ...         ...                       ...       ...       ...
# 4995          1                122.533333    424.40    424.40
# 4996          0               2623.570000  19082.87  22263.37
# 4997          1               1914.070000   2860.13   2952.13
# 4998          1                 35.048000    528.24    528.24
# 4999          1                200.633333   1244.62   1244.62
#
#       Days_since_last_rech_MA  Days_since_last_rech_DA  Last_rech_amt_MA  \
# 0                         2.0                      0.0              1539
# ...

# %%
sb.scatterplot(x='payback90',y='Defaulter',data=a)

# %%
sb.scatterplot(x='AmountSpentMA(Avg90days)',y='Defaulter',data=a)

# %%
sb.scatterplot(x='medianamnt_loans90',y='Defaulter',data=mc)

# %%
sb.scatterplot(x='maxamnt_loans90',y='Defaulter',data=mc)

# %%
sb.scatterplot(x='amnt_loans90',y='Defaulter',data=mc)

# %%
sb.scatterplot(x='cnt_loans90',y='Defaulter',data=mc)

# %%
sb.scatterplot(x='maxamnt_loans30',y='Defaulter',data=mc)

# %% [markdown]
# # Treating Outliers

# %%
mc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 33 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Defaulter                   209593 non-null  int64
#  1   AmountSpentMA(Avg90days)    209593 non-null  float64
#  2   rental30                    209593 non-null  float64
#  3   rental90                    209593 non-null  float64
#  4   Days_since_last_rech_MA     209593 non-null  float64
#  5   Days_since_last_rech_DA     209593 non-null  float64
#  6   Last_rech_amt_MA            209593 non-null  int64
#  7   MA_rech_No_30days           209593 non-null  int64
#  8   fr_ma_rech30                209593 non-null  float64
#  9   TA_charge_MA_30days         209593 non-null  float64
#  10  MedianAmt_chrg_30Days_MA    209593 non-null  float64
#  11  MedianAmt_chrg_B430Days_MA  209593 non-null  float64
# ...

# %%
import scipy
from scipy.stats import zscore
z=np.abs(zscore(mc))

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([    21,     22,     22, ..., 209586, 209587, 209587], dtype=int64), array([13, 13, 30, ..., 26, 24, 28], dtype=int64))

# %%
mc_new=mc[(z<3).all(axis=1)]

# %%
print(mc.shape)
print(mc_new.shape)
# Out:
# (209593, 33)
# (163313, 33)

# %%
sb.boxplot(mc,orient='h')

# %%
sb.boxplot(mc_new,orient='h')

# %% [markdown]
# # Checking Skewness

# %%
mc_new.skew()
# Out:
# Defaulter                     -2.090194
# AmountSpentMA(Avg90days)       2.120623
# rental30                       2.189467
# rental90                       2.239505
# Days_since_last_rech_MA        3.106042
# Days_since_last_rech_DA       10.382586
# Last_rech_amt_MA               2.121573
# MA_rech_No_30days              1.174996
# fr_ma_rech30                   2.005137
# TA_charge_MA_30days            1.643348
# MedianAmt_chrg_30Days_MA       2.321837
# MedianAmt_chrg_B430Days_MA    10.486167
# Freq_MA_rech_90days            1.319886
# fr_ma_rech90                   1.985050
# TA_chrg_MA_90Days              1.713474
# MedianAmt_chrg_MA_90Days       2.369309
# MedianAmt_chrg_B490Days_MA     3.695413
# cnt_da_rech30                 51.050977
# fr_da_rech30                   0.000000
# cnt_da_rech90                  6.935709
# fr_da_rech90                   0.000000
# cnt_loans30                    1.463519
# amnt_loans30                   1.440026
# ...

# %%
mc_new.hist(figsize=(20,20))
plt.show()

# %% [markdown]
# # Splitting Data

# %%
x=mc_new.drop('Defaulter',axis=1)
y=mc_new.Defaulter.values.reshape(-1,1)

# %%
print(y.shape)
print(x.shape)
# Out:
# (163313, 1)
# (163313, 32)

# %%
from sklearn.preprocessing import PowerTransformer
p=PowerTransformer(method='yeo-johnson',standardize=True)
import warnings
warnings.filterwarnings('ignore')

# %%
x=pd.DataFrame(p.fit_transform(x),columns=x.columns)

# %%
x.skew()
# Out:
# AmountSpentMA(Avg90days)      -2.104400
# rental30                       0.204616
# rental90                       0.227636
# Days_since_last_rech_MA        0.125428
# Days_since_last_rech_DA      -59.625286
# Last_rech_amt_MA              -0.184506
# MA_rech_No_30days             -0.026524
# fr_ma_rech30                   0.137315
# TA_charge_MA_30days           -0.455061
# MedianAmt_chrg_30Days_MA      -0.312407
# MedianAmt_chrg_B430Days_MA     1.997328
# Freq_MA_rech_90days           -0.029996
# fr_ma_rech90                   0.142625
# TA_chrg_MA_90Days             -0.363014
# MedianAmt_chrg_MA_90Days      -0.174798
# MedianAmt_chrg_B490Days_MA     0.996680
# cnt_da_rech30                  9.773025
# fr_da_rech30                   0.000000
# cnt_da_rech90                  6.935709
# fr_da_rech90                   0.000000
# cnt_loans30                    0.086094
# amnt_loans30                  -0.003056
# maxamnt_loans30               -0.996065
# ...

# %%
import pylab
import scipy
from scipy import stats

# %%
plt.figure(figsize=(8,5))
plt.subplot(1,2,1)
x['Days_since_last_rech_DA'].hist()
plt.subplot(1,2,2)
stats.probplot(x.Days_since_last_rech_DA,dist='norm',plot=pylab)
plt.show()

# %%
x.hist(figsize=(20,20))
plt.show()

# %% [markdown]
# # Scaling Data

# %%
from sklearn.preprocessing import RobustScaler

# %%
r=RobustScaler()
x=pd.DataFrame(r.fit_transform(x),columns=x.columns)

# %%
x
# Out:
#         AmountSpentMA(Avg90days)  rental30  rental90  Days_since_last_rech_MA  \
# 0                       0.284962 -0.319651 -0.306412                -0.175437
# 1                       0.680415  1.087154  0.809526                 2.407035
# 2                       0.095912  0.004013 -0.060541                 0.000000
# 3                      -0.584710 -0.353071 -0.351264                 4.876529
# 4                      -0.325275  0.090032  0.009015                 0.167476
# ...                          ...       ...       ...                      ...
# 163308                 -0.323979  0.085885  0.005665                -0.362191
# 163309                 -0.520424  0.349384  0.218101                 0.167476
# 163310                  0.674535  1.836890  2.188133                 0.000000
# 163311                  0.692137 -0.221424 -0.030728                -0.175437
# 163312                  0.388730 -0.186386 -0.158647                 1.492535
#
# ...

# %% [markdown]
# # Testing Models

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.model_selection import cross_val_score

# %% [markdown]
# The errors pretty more as the data set is imbalanced let's correct the data set

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
r=RandomOverSampler(0.20)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)

# %%
x_trainr,y_trainr=r.fit_sample(x_train,y_train)

# %%
def m(cls,x,y):
    print('***************',cls,'***************')
    cls.fit(x_trainr,y_trainr)
    pred=lr.predict(x_test)
    acc=accuracy_score(pred,y_test)
    conf=confusion_matrix(pred,y_test)
    cv=cross_val_score(cls,x,y,cv=5,scoring='accuracy').mean()
    print('Accuracy Score Is',acc)
    print('Confusion Matrix','\n',conf)
    print('Cross Value Score is',cv)

# %%
lr=LogisticRegression()

# %%
a=m(lr,x,y)
# Out:
# *************** LogisticRegression() ***************
# Accuracy Score Is 0.8765575727887824
# Confusion Matrix
#  [[ 1501   950]
#  [ 3082 27130]]
# Cross Value Score is 0.8743149663497556

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

# %%
gb=GaussianNB()

# %%
a=m(gb,x,y)
# Out:
# *************** GaussianNB() ***************
# Accuracy Score Is 0.8765575727887824
# Confusion Matrix
#  [[ 1501   950]
#  [ 3082 27130]]
# Cross Value Score is 0.733505600891537

# %%
def grid(model,parameters):
    g=GridSearchCV(model,parameters,cv=5)
    g.fit(x_train,y_train)
    return g.best_params_

# %%
dt=DecisionTreeClassifier()
parameters={'criterion':['gini','entropy']}

# %%
a=grid(dt,parameters)

# %%
a
# Out:
# {'criterion': 'entropy'}

# %%
dt=DecisionTreeClassifier(criterion='entropy')

# %%
def n(cls,x,y):
    print('***************',cls,'***************')
    cls.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=accuracy_score(pred,y_test)
    conf=confusion_matrix(pred,y_test)
    cv=cross_val_score(cls,x,y,cv=5,scoring='accuracy').mean()
    print('Accuracy Score Is',acc)
    print('Confusion Matrix','\n',conf)
    print('Cross Value Score is',cv)

# %%
a=n(dt,x,y)
# Out:
# *************** DecisionTreeClassifier(criterion='entropy') ***************
# Accuracy Score Is 0.8765575727887824
# Confusion Matrix
#  [[ 1501   950]
#  [ 3082 27130]]
# Cross Value Score is 0.8808545568734629

# %%
import joblib

# %%
joblib.dump(a,'MicroCredit.obj')
# Out:
# ['MicroCredit.obj']
